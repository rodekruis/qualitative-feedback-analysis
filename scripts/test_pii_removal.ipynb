# %%
import os

while "pyproject.toml" not in os.listdir():
    os.chdir("..")

# %%
from src.qfa.services.orchestrator import Orchestrator

orch = Orchestrator(
    llm=None, settings=None, llm_timeout_seconds=20, max_total_tokens=20
)

# %%
anonymized_string, mapping = orch.anonymize(
    "Amsterdam is my city. Did you hear me, Amsterdam is my city! My name is John"
)
anonymized_string, mapping

# %%
orch.deanonymize(anonymized_string, mapping)
